# %%
import os, json, joblib, numpy as np, pandas as pd
from pathlib import Path
import warnings 
warnings.filterwarnings("ignore")

from scipy.spatial.transform import Rotation as R

from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras.utils import Sequence, to_categorical, pad_sequences
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, LayerNormalization, Activation, add, MaxPooling1D, Dropout,
    Bidirectional, LSTM, GlobalAveragePooling1D, Dense, Multiply, Reshape,
    Lambda, Concatenate, GRU, GaussianNoise
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
import tensorflow as tf
import polars as pl

import matplotlib.pyplot as plt
# Out:
# 2025-09-01 11:13:18.426740: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-01 11:13:18.822643: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756714398.960767    5218 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756714399.003426    5218 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-01 11:13:19.379912: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices("GPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#print(tf.sysconfig.get_build_info())

# %%
print("GPU count:", len(tf.config.list_physical_devices('GPU')))
# Out:
# GPU count: 1

# %%
state = 28
import random
def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.experimental.numpy.random.seed(seed)
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
seed_everything(seed=state)

# %%
# (Competition metric will only be imported when TRAINing)
TRAIN = True
DEBUG_GATE = False

RAW_DIR = Path("")
PRETRAINED_DIR = Path("new_model_10_fold")
EXPORT_DIR = Path("hier_ls28")
BATCH_SIZE = 64
PAD_PERCENTILE = 95
LR_INIT = 5e-4
WD = 3e-3
MIXUP_ALPHA = 0.4
EPOCHS = 160
PATIENCE = 40
N_SPLITS = 10
MASKING_PROB = 0.25
GATE_LOSS_WEIGHT = 0.20 # 0.20

print("▶ imports ready · tensorflow", tf.__version__)
# Out:
# ▶ imports ready · tensorflow 2.18.0

# %%
def remove_gravity_from_acc(acc_data, rot_data):
    acc_values = acc_data[['acc_x', 'acc_y', 'acc_z']].values
    quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    linear_accel = np.zeros_like(acc_values)
    gravity_world = np.array([0, 0, 9.81])
    for i in range(len(acc_values)):
        if np.all(np.isnan(quat_values[i])) or np.all(np.isclose(quat_values[i], 0)):
            linear_accel[i, :] = acc_values[i, :]
            continue
        try:
            rotation = R.from_quat(quat_values[i])
            gravity_sensor_frame = rotation.apply(gravity_world, inverse=True)
            linear_accel[i, :] = acc_values[i, :] - gravity_sensor_frame
        except ValueError:
             linear_accel[i, :] = acc_values[i, :]
    return linear_accel

def calculate_angular_velocity_from_quat(rot_data, time_delta=1/200):
    quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    angular_vel = np.zeros((len(quat_values), 3))
    for i in range(len(quat_values) - 1):
        q_t, q_t_plus_dt = quat_values[i], quat_values[i+1]
        if np.all(np.isnan(q_t)) or np.all(np.isnan(q_t_plus_dt)): continue
        try:
            rot_t = R.from_quat(q_t)
            rot_t_plus_dt = R.from_quat(q_t_plus_dt)
            delta_rot = rot_t.inv() * rot_t_plus_dt
            angular_vel[i, :] = delta_rot.as_rotvec() / time_delta
        except ValueError: pass
    return angular_vel

def calculate_angular_distance(rot_data):
    quat_values = rot_data[['rot_x', 'rot_y', 'rot_z', 'rot_w']].values
    angular_dist = np.zeros(len(quat_values))
    for i in range(len(quat_values) - 1):
        q1, q2 = quat_values[i], quat_values[i+1]
        if np.all(np.isnan(q1)) or np.all(np.isnan(q2)): continue
        try:
            r1, r2 = R.from_quat(q1), R.from_quat(q2)
            relative_rotation = r1.inv() * r2
            angular_dist[i] = np.linalg.norm(relative_rotation.as_rotvec())
        except ValueError: pass
    return angular_dist

# %%
# Tensor Manipulations
def time_sum(x): return K.sum(x, axis=1)
def squeeze_last_axis(x): return tf.squeeze(x, axis=-1)
def expand_last_axis(x): return tf.expand_dims(x, axis=-1)

def se_block(x, reduction=8):
    ch = x.shape[-1]
    se = GlobalAveragePooling1D()(x)
    se = Dense(ch // reduction, activation='relu')(se)
    se = Dense(ch, activation='sigmoid')(se)
    se = Reshape((1, ch))(se)
    return Multiply()([x, se])

# %%
class GatedMixupGenerator(Sequence):
    def __init__(self, X, y, batch_size, imu_dim, class_weight=None, alpha=0.2, masking_prob=0.0, shuffle=True):
        self.X, self.y = X, y
        self.batch = batch_size
        self.imu_dim = imu_dim
        self.class_weight = class_weight
        self.alpha = alpha
        self.masking_prob = masking_prob
        self.indices = np.arange(len(X))
        self.shuffle=shuffle
        
    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch))

    def __getitem__(self, i):
        idx = self.indices[i*self.batch:(i+1)*self.batch]
        Xb, yb = self.X[idx].copy(), self.y[idx].copy()
        
        
        sample_weights = np.ones(len(Xb), dtype='float32')
        if self.class_weight:
            y_integers = yb.argmax(axis=1)
            sample_weights = np.array([self.class_weight[i] for i in y_integers])
        
        gate_target = np.ones(len(Xb), dtype='float32')
        if self.masking_prob > 0:
            for i in range(len(Xb)):
                if np.random.rand() < self.masking_prob:
                    Xb[i, :, self.imu_dim:] = 0
                    gate_target[i] = 0.0

        if self.alpha > 0:
            lam = np.random.beta(self.alpha, self.alpha)
            perm = np.random.permutation(len(Xb))
            X_mix = lam * Xb + (1 - lam) * Xb[perm]
            y_mix = lam * yb + (1 - lam) * yb[perm]
            gate_target_mix = lam * gate_target + (1 - lam) * gate_target[perm]
            sample_weights_mix = lam * sample_weights + (1 - lam) * sample_weights[perm]
            return X_mix, {'main_output': y_mix, 'tof_gate': gate_target_mix}, sample_weights_mix

        return Xb, {'main_output': yb, 'tof_gate': gate_target}, sample_weights

    def on_epoch_end(self):
        #if self.shuffle:
        np.random.shuffle(self.indices)

# %%
# HIERARCHICAL 0.817LB
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import tensorflow.keras.backend as K

# --- Residual CNN Blok ---
def residual_se_cnn_block(x, filters, kernel_size, drop, wd):
    y = Conv1D(filters, kernel_size, padding='same', use_bias=False, kernel_regularizer=l2(wd))(x)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = SpatialDropout1D(drop)(y)
    y = Conv1D(filters, kernel_size, padding='same', use_bias=False, kernel_regularizer=l2(wd))(y)
    y = BatchNormalization()(y)
    if x.shape[-1] != filters:
        x = Conv1D(filters, 1, padding='same', use_bias=False, kernel_regularizer=l2(wd))(x)
    return Activation('relu')(Add()([x, y]))

# --- Transformer Encoder Bloğu ---
class TransformerEncoderBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.3, wd=5e-4, **kwargs):
        super().__init__(**kwargs)
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim // num_heads)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu", kernel_regularizer=l2(wd)),
            Dense(embed_dim, kernel_regularizer=l2(wd)),
        ])
        self.norm1 = BatchNormalization()
        self.norm2 = BatchNormalization()
        self.drop1 = Dropout(rate)
        self.drop2 = Dropout(rate)

    def call(self, inputs):
        attn_out = self.att(inputs, inputs)
        x = self.norm1(inputs + self.drop1(attn_out))
        ffn_out = self.ffn(x)
        return self.norm2(x + self.drop2(ffn_out))

# --- Positional Embedding ---
class PositionalEmbedding(Layer):
    def __init__(self, sequence_length, output_dim):
        super().__init__()
        self.position_embeddings = Embedding(input_dim=sequence_length, output_dim=output_dim)

    def call(self, inputs):
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        return inputs + self.position_embeddings(positions)

# --- Model ---
def build_hierarchical_transformer_model(pad_len, imu_dim, tof_dim, n_classes, wd=5e-4):
    inp = Input(shape=(pad_len, imu_dim + tof_dim), name='main_input')
    imu_input = Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof_input = Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU ---
    imu = residual_se_cnn_block(imu_input, 64, 3, drop=0.3, wd=wd)
    imu = residual_se_cnn_block(imu, 128, 5, drop=0.3, wd=wd)
    imu = MaxPooling1D(2)(imu)
    imu = MaxPooling1D(2)(imu)
    imu = PositionalEmbedding(imu.shape[1], imu.shape[2])(imu)
    imu = TransformerEncoderBlock(embed_dim=imu.shape[-1], num_heads=4, ff_dim=256, rate=0.3, wd=wd)(imu)

    # --- ToF ---
    tof = Conv1D(64, 3, padding='same', use_bias=False, kernel_regularizer=l2(wd))(tof_input)
    tof = BatchNormalization()(tof)
    tof = Activation('relu')(tof)
    tof = MaxPooling1D(2)(tof)
    tof = SpatialDropout1D(0.3)(tof)
    tof = Conv1D(128, 3, padding='same', use_bias=False, kernel_regularizer=l2(wd))(tof)
    tof = BatchNormalization()(tof)
    tof = Activation('relu')(tof)
    tof = MaxPooling1D(2)(tof)
    tof = SpatialDropout1D(0.4)(tof)
    tof = PositionalEmbedding(tof.shape[1], tof.shape[2])(tof)
    tof = TransformerEncoderBlock(embed_dim=tof.shape[-1], num_heads=4, ff_dim=256, rate=0.3, wd=wd)(tof)

    # --- Cross Attention ---
    imu_to_tof = MultiHeadAttention(num_heads=4, key_dim=tof.shape[-1] // 4)(tof, imu, imu)
    imu_to_tof = Dropout(0.2)(imu_to_tof)
    tof_merged = BatchNormalization()(Add()([tof, imu_to_tof]))

    tof_to_imu = MultiHeadAttention(num_heads=4, key_dim=imu.shape[-1] // 4)(imu, tof, tof)
    tof_to_imu = Dropout(0.2)(tof_to_imu)
    imu_merged = BatchNormalization()(Add()([imu, tof_to_imu]))

    # --- Fuse ---
    merged = Concatenate()([imu_merged, tof_merged])
    gate_input = GlobalAveragePooling1D()(merged)
    gate_input = Dense(32, activation='relu', kernel_regularizer=l2(wd))(gate_input)
    gate = Dense(1, activation='sigmoid', name='tof_gate', kernel_regularizer=l2(wd))(gate_input)
    gate_expanded = RepeatVector(merged.shape[1])(gate)
    gated = Multiply()([merged, gate_expanded])

    # --- Global Context Transformer ---
    context = TransformerEncoderBlock(embed_dim=gated.shape[-1], num_heads=8, ff_dim=256, rate=0.4, wd=wd)(gated)
    x = GlobalAveragePooling1D()(context)

    for units, drop in [(256, 0.5), (128, 0.4)]:
        x = Dense(units, use_bias=False, kernel_regularizer=l2(wd))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Dropout(drop)(x)

    out = Dense(n_classes, activation='softmax', name='main_output', kernel_regularizer=l2(wd))(x)

    return Model(inputs=inp, outputs=[out, gate])

# %%
from scipy.ndimage import sobel

# ToF için spatial gradyan (sobel) temelli özellikler
def calculate_spatial_tof_features(seq_df, sensor_id):
    # 1D 64-pikseli 8x8'e reshape edip sobel gradyanı alacağız
    pixel_cols = [f"tof_{sensor_id}_v{p}" for p in range(64)]
    tof_data = seq_df[pixel_cols].replace(-1, np.nan).ffill().bfill().fillna(0).values
    
    # Frame sayısı x 64 → (N x 8 x 8)
    N = len(seq_df)
    reshaped = tof_data.reshape(N, 8, 8)
    
    # Spatial gradyanları hesapla (sobel x ve y)
    sobel_x = sobel(reshaped, axis=1)
    sobel_y = sobel(reshaped, axis=2)
    grad_mag = np.sqrt(sobel_x ** 2 + sobel_y ** 2)

    # Özet istatistikleri hesapla
    grad_mean = grad_mag.mean(axis=(1, 2))
    grad_std  = grad_mag.std(axis=(1, 2))
    grad_max  = grad_mag.max(axis=(1, 2))
    
    return pd.DataFrame({
        f'tof_{sensor_id}_grad_mean': grad_mean,
        f'tof_{sensor_id}_grad_std': grad_std,
        f'tof_{sensor_id}_grad_max': grad_max
    }, index=seq_df.index)

# %%
if TRAIN: 
    print("▶ TRAIN MODE – loading dataset ...")
    df = pd.read_csv(RAW_DIR / "train.csv")
    
    train_dem_df = pd.read_csv(RAW_DIR / "train_demographics.csv")

    le = LabelEncoder()
    df['gesture_int'] = le.fit_transform(df['gesture'])
    np.save(EXPORT_DIR / "gesture_classes.npy", le.classes_)

    acc_y_neg_subjects = (
        df.groupby('subject')['acc_y']
        .mean()
        .loc[lambda x: x < 0]
        .index
        .tolist()
    )

    print("acc_y ortalaması negatif olan subject'ler:", acc_y_neg_subjects)
    df = df[~df['subject'].isin(acc_y_neg_subjects)].reset_index(drop=True)
    
    print("  Removing gravity and calculating linear acceleration features...")
    linear_accel_list = [pd.DataFrame(remove_gravity_from_acc(group[['acc_x', 'acc_y', 'acc_z']], group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]), columns=['linear_acc_x', 'linear_acc_y', 'linear_acc_z'], index=group.index) for _, group in df.groupby('sequence_id')]
    df = pd.concat([df, pd.concat(linear_accel_list)], axis=1)
    
    df['linear_acc_mag'] = np.sqrt(df['linear_acc_x']**2 + df['linear_acc_y']**2 + df['linear_acc_z']**2)
    df['linear_acc_mag_jerk'] = df.groupby('sequence_id')['linear_acc_mag'].diff().fillna(0)
    
    print("  Calculating angular velocity and distance from quaternions...")
    angular_vel_list = [pd.DataFrame(calculate_angular_velocity_from_quat(group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]), columns=['angular_vel_x', 'angular_vel_y', 'angular_vel_z'], index=group.index) for _, group in df.groupby('sequence_id')]
    df = pd.concat([df, pd.concat(angular_vel_list)], axis=1)
    angular_dist_list = [pd.DataFrame(calculate_angular_distance(group[['rot_x', 'rot_y', 'rot_z', 'rot_w']]), columns=['angular_distance'], index=group.index) for _, group in df.groupby('sequence_id')]
    df = pd.concat([df, pd.concat(angular_dist_list)], axis=1)

    for col in ['acc_x', 'acc_y', 'acc_z',  'linear_acc_x', 'linear_acc_y', 'linear_acc_z', 'angular_vel_x', 'angular_vel_y', 'angular_vel_z']:
        if col in df.columns:
            df[f'{col}_diff'] = df.groupby('sequence_id')[col].diff().fillna(0)
            df[f'{col}_abs_diff'] = np.abs(df.groupby('sequence_id')[col].diff()).fillna(0)

    imu_cols_base = ['acc_x', 'acc_y', 'acc_z'] + [c for c in df.columns if c.startswith('rot_')]
    imu_engineered = [
    'linear_acc_mag', 'linear_acc_mag_jerk',
    'angular_vel_x', 'angular_vel_y', 'angular_vel_z', 'angular_distance'
    ]
    for col in ['acc_x', 'acc_y', 'acc_z', 'linear_acc_x', 'linear_acc_y', 'linear_acc_z', 'angular_vel_x', 'angular_vel_y', 'angular_vel_z']:
        if col in df.columns:
            imu_engineered.append(f'{col}_diff')
            imu_engineered.append(f'{col}_abs_diff')
    imu_cols = list(dict.fromkeys(imu_cols_base + imu_engineered))
    
    thm_cols_original = [c for c in df.columns if c.startswith('thm_')]
    
    tof_aggregated_cols_template = []
    for i in range(1, 6): tof_aggregated_cols_template.extend([f'tof_{i}_mean', f'tof_{i}_std', f'tof_{i}_min', f'tof_{i}_max'])

    for i in range(1, 6):
        tof_aggregated_cols_template.extend([
            f'tof_{i}_grad_mean', f'tof_{i}_grad_std', f'tof_{i}_grad_max'
        ])
    
    final_feature_cols = imu_cols + thm_cols_original + tof_aggregated_cols_template

    imu_dim_final = len(imu_cols)
    tof_thm_aggregated_dim_final = len(thm_cols_original) + len(tof_aggregated_cols_template)
    
    print(f"  IMU (phys-based + enhanced) {imu_dim_final} | THM + Aggregated TOF {tof_thm_aggregated_dim_final} | total {len(final_feature_cols)} features")
    np.save(EXPORT_DIR / "feature_cols.npy", np.array(final_feature_cols))

    print("  Building sequences...")
    seq_gp = df.groupby('sequence_id')
    X_list_unscaled, y_list_int, groups_list, lens = [], [], [], []
    for seq_id, seq_df in seq_gp:
        seq_df_copy = seq_df.copy()
        for i in range(1, 6):
            pixel_cols = [f"tof_{i}_v{p}" for p in range(64)]; tof_data = seq_df_copy[pixel_cols].replace(-1, np.nan)
            seq_df_copy[f'tof_{i}_mean'], seq_df_copy[f'tof_{i}_std'], seq_df_copy[f'tof_{i}_min'], seq_df_copy[f'tof_{i}_max'] = tof_data.mean(axis=1), tof_data.std(axis=1), tof_data.min(axis=1), tof_data.max(axis=1)
            
            spatial_feats = calculate_spatial_tof_features(seq_df_copy, i)
            seq_df_copy = pd.concat([seq_df_copy, spatial_feats], axis=1)
        
        X_list_unscaled.append(seq_df_copy[final_feature_cols].ffill().bfill().fillna(0).values.astype('float32'))
        y_list_int.append(seq_df_copy['gesture_int'].iloc[0])
        groups_list.append(seq_df_copy['subject'].iloc[0])
        lens.append(len(seq_df_copy))

    print("  Fitting StandardScaler...")
    all_steps_concatenated = np.concatenate(X_list_unscaled, axis=0)
    scaler = StandardScaler().fit(all_steps_concatenated)
    joblib.dump(scaler, EXPORT_DIR / "scaler.pkl")
    
    print("  Scaling and padding sequences...")
    X_scaled_list = [scaler.transform(x_seq) for x_seq in X_list_unscaled]
    pad_len = int(np.percentile(lens, PAD_PERCENTILE)); np.save(EXPORT_DIR / "sequence_maxlen.npy", pad_len)
    X = pad_sequences(X_scaled_list, maxlen=pad_len, padding='post', truncating='post', dtype='float32')

    subject_acc_x_mean_global = df.groupby('subject')['acc_x'].mean()
    subject_is_acc_x_mean_negative = (subject_acc_x_mean_global < 0).astype(str)
    
    y_stratify = np.array([f"{gesture_label}_{subject_is_acc_x_mean_negative.loc[sub_id]}"
                           for gesture_label, sub_id in zip(y_list_int, groups_list)])
    
    groups, y = np.array(groups_list), to_categorical(y_list_int, num_classes=len(le.classes_))
    print("  Starting training with Stratified Group K-Fold CV...")
    sgkf = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=state) # state_num yerine state kullanıldı
    oof_preds = np.zeros_like(y, dtype='float32')
    
    for fold, (train_idx, val_idx) in enumerate(sgkf.split(X, y_stratify, groups)):
        print(f"\n===== FOLD {fold+1}/{N_SPLITS} =====")
        X_tr, X_val, y_tr, y_val = X[train_idx], X[val_idx], y[train_idx], y[val_idx]# y_val düzeltildi
        
        # --- DEĞİŞİKLİK BAŞLANGICI ---
        # Modelinizi burada çağırın
        model = build_hierarchical_transformer_model(
            pad_len, imu_dim_final, tof_thm_aggregated_dim_final, len(le.classes_), wd=WD
        )

        # Custom katmanları compile ve save/load için kaydet.
        # Bu custom_objects, model.save() ve tf.keras.models.load_model() için gereklidir.
        #custom_objects_for_model = {
         #   'TransformerEncoderBlock': TransformerEncoderBlock,
        #    'PositionalEmbedding': PositionalEmbedding,
            # Eğer residual_se_cnn_block ve attention_layer custom Layer ise, onları da ekleyin.
            # Şu anki tanımlarınız Layer sınıfından kalıtım almadığı için gerekmez,
            # ancak Layer olarak yeniden yazarsanız eklersiniz.
       # }
        # --- DEĞİŞİKLİK SONU ---

        lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_main_output_accuracy',
            mode='max',
            factor=0.5,
            patience=8,
            cooldown=2,
            min_lr=3e-6,
            verbose=1
        )
        
     
        
        model.compile(optimizer=Adam(LR_INIT),
                      loss={'main_output': tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                             'tof_gate': tf.keras.losses.BinaryCrossentropy()
                             },
                      loss_weights={'main_output': 1.0,
                                     'tof_gate': GATE_LOSS_WEIGHT,
                                     },
                      metrics={'main_output': 'accuracy'})
        
        class_weight_dict = dict(enumerate(compute_class_weight('balanced', classes=np.arange(len(le.classes_)), y=y_tr.argmax(1))))
        
        train_gen = GatedMixupGenerator(X_tr, y_tr, batch_size=BATCH_SIZE, imu_dim=imu_dim_final, class_weight=class_weight_dict, alpha=MIXUP_ALPHA, masking_prob=MASKING_PROB, shuffle=True)
        val_gen = GatedMixupGenerator(X_val, y_val, batch_size=BATCH_SIZE, imu_dim=imu_dim_final,class_weight=None, alpha=0.2, shuffle=False) # İmu_dim burada da doğru olmalı

       

        cb = [
            EarlyStopping(patience=PATIENCE, restore_best_weights=True, verbose=1, monitor='val_main_output_accuracy', mode='max'),
            lr_scheduler
        ]
        
        model.fit(train_gen, epochs=EPOCHS, validation_data=val_gen, callbacks=cb, verbose=1)
        
        # --- DEĞİŞİKLİK BAŞLANGICI ---
        # Modeli custom_objects ile kaydedin
        model_save_path = EXPORT_DIR / f"gesture_model_fold_{fold}" # .h5 uzantısı olmadan bir dizin adı
        tf.saved_model.save(model, str(model_save_path)) # SavedModel formatında kaydet
        print(f"Model kaydedildi: {model_save_path}")
        # --- DEĞİŞİKLİK SONU ---

        preds_val, _ = model.predict(X_val)
        oof_preds[val_idx] = preds_val

    print("\n✔ Training done.")
    
    from metric import CompetitionMetric # Import path needs to be correct
    true_oof_int = y.argmax(1)
    pred_oof_int = oof_preds.argmax(1)
        
    h_f1_oof = CompetitionMetric().calculate_hierarchical_f1(
        pd.DataFrame({'gesture': le.classes_[true_oof_int]}),
        pd.DataFrame({'gesture': le.classes_[pred_oof_int]}))
    print(f"Overall OOF H‑F1 Score = {h_f1_oof:.4f}")
# Out:
# ▶ TRAIN MODE – loading dataset ...
# acc_y ortalaması negatif olan subject'ler: ['SUBJ_019262', 'SUBJ_045235']
#   Removing gravity and calculating linear acceleration features...
#   Calculating angular velocity and distance from quaternions...
#   IMU (phys-based + enhanced) 31 | THM + Aggregated TOF 40 | total 71 features
#   Building sequences...
#   Fitting StandardScaler...
#   Scaling and padding sequences...
#   Starting training with Stratified Group K-Fold CV...
#
# ===== FOLD 1/10 =====
# I0000 00:00:1756714550.767424    5218 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21770 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/160
# I0000 00:00:1756714559.256584    5872 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - loss: 10.0450 - main_output_accuracy: 0.0904 - main_output_loss: 3.2480 - tof_gate_loss: 0.6515 - val_loss: 8.6277 - val_main_output_accuracy: 0.2120 - val_main_output_loss: 2.6453 - val_tof_gate_loss: 0.3153 - learning_rate: 5.0000e-04
# Epoch 2/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 8.5331 - main_output_accuracy: 0.1422 - main_output_loss: 2.8321 - tof_gate_loss: 0.3472 - val_loss: 7.2601 - val_main_output_accuracy: 0.2757 - val_main_output_loss: 2.4027 - val_tof_gate_loss: 0.1099 - learning_rate: 5.0000e-04
# Epoch 3/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 7.2728 - main_output_accuracy: 0.1874 - main_output_loss: 2.6243 - tof_gate_loss: 0.3400 - val_loss: 6.1374 - val_main_output_accuracy: 0.3493 - val_main_output_loss: 2.2553 - val_tof_gate_loss: 0.0847 - learning_rate: 5.0000e-04
# Epoch 4/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 6.1216 - main_output_accuracy: 0.2520 - main_output_loss: 2.4057 - tof_gate_loss: 0.2998 - val_loss: 5.1512 - val_main_output_accuracy: 0.4571 - val_main_output_loss: 2.0534 - val_tof_gate_loss: 0.1097 - learning_rate: 5.0000e-04
# Epoch 5/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 5.3248 - main_output_accuracy: 0.2934 - main_output_loss: 2.3538 - tof_gate_loss: 0.3093 - val_loss: 4.5465 - val_main_output_accuracy: 0.3885 - val_main_output_loss: 2.0747 - val_tof_gate_loss: 0.0917 - learning_rate: 5.0000e-04
# Epoch 6/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - loss: 4.6796 - main_output_accuracy: 0.3098 - main_output_loss: 2.2942 - tof_gate_loss: 0.3298 - val_loss: 3.9247 - val_main_output_accuracy: 0.4877 - val_main_output_loss: 1.9410 - val_tof_gate_loss: 0.1055 - learning_rate: 5.0000e-04
# Epoch 7/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - loss: 4.1097 - main_output_accuracy: 0.3488 - main_output_loss: 2.1886 - tof_gate_loss: 0.3024 - val_loss: 3.5590 - val_main_output_accuracy: 0.4730 - val_main_output_loss: 1.9594 - val_tof_gate_loss: 0.1079 - learning_rate: 5.0000e-04
# Epoch 8/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 3.6817 - main_output_accuracy: 0.3781 - main_output_loss: 2.1117 - tof_gate_loss: 0.2940 - val_loss: 3.3316 - val_main_output_accuracy: 0.4473 - val_main_output_loss: 2.0069 - val_tof_gate_loss: 0.1538 - learning_rate: 5.0000e-04
# Epoch 9/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 3.4633 - main_output_accuracy: 0.3917 - main_output_loss: 2.1528 - tof_gate_loss: 0.3290 - val_loss: 2.9478 - val_main_output_accuracy: 0.5025 - val_main_output_loss: 1.8311 - val_tof_gate_loss: 0.1339 - learning_rate: 5.0000e-04
# Epoch 10/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 3.2055 - main_output_accuracy: 0.4049 - main_output_loss: 2.1008 - tof_gate_loss: 0.3222 - val_loss: 2.8197 - val_main_output_accuracy: 0.4865 - val_main_output_loss: 1.8780 - val_tof_gate_loss: 0.1253 - learning_rate: 5.0000e-04
# Epoch 11/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 3.0102 - main_output_accuracy: 0.4109 - main_output_loss: 2.0713 - tof_gate_loss: 0.3078 - val_loss: 2.5192 - val_main_output_accuracy: 0.5429 - val_main_output_loss: 1.7221 - val_tof_gate_loss: 0.0999 - learning_rate: 5.0000e-04
# Epoch 12/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 2.8506 - main_output_accuracy: 0.4275 - main_output_loss: 2.0410 - tof_gate_loss: 0.2864 - val_loss: 2.4098 - val_main_output_accuracy: 0.5650 - val_main_output_loss: 1.7166 - val_tof_gate_loss: 0.0954 - learning_rate: 5.0000e-04
# Epoch 13/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - loss: 2.6946 - main_output_accuracy: 0.4394 - main_output_loss: 1.9813 - tof_gate_loss: 0.2882 - val_loss: 2.4285 - val_main_output_accuracy: 0.5257 - val_main_output_loss: 1.8217 - val_tof_gate_loss: 0.1162 - learning_rate: 5.0000e-04
# Epoch 14/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 2.6573 - main_output_accuracy: 0.4368 - main_output_loss: 2.0209 - tof_gate_loss: 0.3071 - val_loss: 2.2114 - val_main_output_accuracy: 0.5760 - val_main_output_loss: 1.6655 - val_tof_gate_loss: 0.1038 - learning_rate: 5.0000e-04
# Epoch 15/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 2.5704 - main_output_accuracy: 0.4538 - main_output_loss: 1.9982 - tof_gate_loss: 0.3057 - val_loss: 2.2234 - val_main_output_accuracy: 0.5404 - val_main_output_loss: 1.7385 - val_tof_gate_loss: 0.0883 - learning_rate: 5.0000e-04
# Epoch 16/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 2.5360 - main_output_accuracy: 0.4675 - main_output_loss: 2.0177 - tof_gate_loss: 0.3040 - val_loss: 2.2112 - val_main_output_accuracy: 0.5441 - val_main_output_loss: 1.7624 - val_tof_gate_loss: 0.0958 - learning_rate: 5.0000e-04
# Epoch 17/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - loss: 2.4375 - main_output_accuracy: 0.4770 - main_output_loss: 1.9632 - tof_gate_loss: 0.3015 - val_loss: 2.0098 - val_main_output_accuracy: 0.5993 - val_main_output_loss: 1.6093 - val_tof_gate_loss: 0.0628 - learning_rate: 5.0000e-04
# Epoch 18/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 2.2994 - main_output_accuracy: 0.4979 - main_output_loss: 1.8590 - tof_gate_loss: 0.2940 - val_loss: 2.0852 - val_main_output_accuracy: 0.5907 - val_main_output_loss: 1.7020 - val_tof_gate_loss: 0.1003 - learning_rate: 5.0000e-04
# Epoch 19/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 2.2865 - main_output_accuracy: 0.5171 - main_output_loss: 1.8774 - tof_gate_loss: 0.2909 - val_loss: 2.1248 - val_main_output_accuracy: 0.5944 - val_main_output_loss: 1.7743 - val_tof_gate_loss: 0.1053 - learning_rate: 5.0000e-04
# Epoch 20/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 117ms/step - loss: 2.2706 - main_output_accuracy: 0.5152 - main_output_loss: 1.8869 - tof_gate_loss: 0.2878 - val_loss: 2.0028 - val_main_output_accuracy: 0.5797 - val_main_output_loss: 1.6810 - val_tof_gate_loss: 0.1066 - learning_rate: 5.0000e-04
# Epoch 21/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 2.2487 - main_output_accuracy: 0.5218 - main_output_loss: 1.8802 - tof_gate_loss: 0.2985 - val_loss: 1.8402 - val_main_output_accuracy: 0.6225 - val_main_output_loss: 1.5307 - val_tof_gate_loss: 0.0583 - learning_rate: 5.0000e-04
# Epoch 22/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 2.2582 - main_output_accuracy: 0.5159 - main_output_loss: 1.9051 - tof_gate_loss: 0.3111 - val_loss: 1.8514 - val_main_output_accuracy: 0.6201 - val_main_output_loss: 1.5523 - val_tof_gate_loss: 0.0732 - learning_rate: 5.0000e-04
# Epoch 23/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 2.3007 - main_output_accuracy: 0.5353 - main_output_loss: 1.9667 - tof_gate_loss: 0.3066 - val_loss: 1.9517 - val_main_output_accuracy: 0.6262 - val_main_output_loss: 1.6783 - val_tof_gate_loss: 0.0791 - learning_rate: 5.0000e-04
# Epoch 24/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 2.2211 - main_output_accuracy: 0.5145 - main_output_loss: 1.8989 - tof_gate_loss: 0.3029 - val_loss: 1.9156 - val_main_output_accuracy: 0.5882 - val_main_output_loss: 1.6620 - val_tof_gate_loss: 0.0719 - learning_rate: 5.0000e-04
# Epoch 25/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 2.1155 - main_output_accuracy: 0.5518 - main_output_loss: 1.8040 - tof_gate_loss: 0.2874 - val_loss: 1.8121 - val_main_output_accuracy: 0.6446 - val_main_output_loss: 1.5598 - val_tof_gate_loss: 0.0620 - learning_rate: 5.0000e-04
# Epoch 26/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 2.1752 - main_output_accuracy: 0.5295 - main_output_loss: 1.8731 - tof_gate_loss: 0.2948 - val_loss: 1.8359 - val_main_output_accuracy: 0.6029 - val_main_output_loss: 1.5886 - val_tof_gate_loss: 0.1114 - learning_rate: 5.0000e-04
# Epoch 27/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 2.0972 - main_output_accuracy: 0.5510 - main_output_loss: 1.8051 - tof_gate_loss: 0.2783 - val_loss: 1.7639 - val_main_output_accuracy: 0.6581 - val_main_output_loss: 1.5122 - val_tof_gate_loss: 0.0973 - learning_rate: 5.0000e-04
# Epoch 28/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 2.1175 - main_output_accuracy: 0.5462 - main_output_loss: 1.8263 - tof_gate_loss: 0.2896 - val_loss: 1.8945 - val_main_output_accuracy: 0.6189 - val_main_output_loss: 1.6579 - val_tof_gate_loss: 0.0844 - learning_rate: 5.0000e-04
# Epoch 29/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 2.2024 - main_output_accuracy: 0.5373 - main_output_loss: 1.9088 - tof_gate_loss: 0.3317 - val_loss: 1.8840 - val_main_output_accuracy: 0.6250 - val_main_output_loss: 1.6525 - val_tof_gate_loss: 0.0941 - learning_rate: 5.0000e-04
# Epoch 30/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 2.0724 - main_output_accuracy: 0.5538 - main_output_loss: 1.7987 - tof_gate_loss: 0.2749 - val_loss: 1.8960 - val_main_output_accuracy: 0.5870 - val_main_output_loss: 1.6612 - val_tof_gate_loss: 0.0862 - learning_rate: 5.0000e-04
# Epoch 31/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 2.1198 - main_output_accuracy: 0.5578 - main_output_loss: 1.8451 - tof_gate_loss: 0.3012 - val_loss: 1.8475 - val_main_output_accuracy: 0.6409 - val_main_output_loss: 1.6318 - val_tof_gate_loss: 0.0598 - learning_rate: 5.0000e-04
# Epoch 32/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 2.0991 - main_output_accuracy: 0.5540 - main_output_loss: 1.8357 - tof_gate_loss: 0.2997 - val_loss: 1.7605 - val_main_output_accuracy: 0.6765 - val_main_output_loss: 1.5386 - val_tof_gate_loss: 0.0455 - learning_rate: 5.0000e-04
# Epoch 33/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 2.0274 - main_output_accuracy: 0.5700 - main_output_loss: 1.7593 - tof_gate_loss: 0.2841 - val_loss: 2.0161 - val_main_output_accuracy: 0.6299 - val_main_output_loss: 1.7820 - val_tof_gate_loss: 0.0808 - learning_rate: 5.0000e-04
# Epoch 34/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 2.1067 - main_output_accuracy: 0.5603 - main_output_loss: 1.8318 - tof_gate_loss: 0.2975 - val_loss: 1.6734 - val_main_output_accuracy: 0.6765 - val_main_output_loss: 1.4625 - val_tof_gate_loss: 0.0479 - learning_rate: 5.0000e-04
# Epoch 35/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - loss: 2.0416 - main_output_accuracy: 0.5897 - main_output_loss: 1.7747 - tof_gate_loss: 0.2816 - val_loss: 1.9653 - val_main_output_accuracy: 0.6164 - val_main_output_loss: 1.7444 - val_tof_gate_loss: 0.0958 - learning_rate: 5.0000e-04
# Epoch 36/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 2.1302 - main_output_accuracy: 0.5640 - main_output_loss: 1.8611 - tof_gate_loss: 0.3076 - val_loss: 1.7887 - val_main_output_accuracy: 0.6262 - val_main_output_loss: 1.5629 - val_tof_gate_loss: 0.0788 - learning_rate: 5.0000e-04
# Epoch 37/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 2.0542 - main_output_accuracy: 0.5742 - main_output_loss: 1.7922 - tof_gate_loss: 0.2815 - val_loss: 1.7445 - val_main_output_accuracy: 0.6544 - val_main_output_loss: 1.5202 - val_tof_gate_loss: 0.0640 - learning_rate: 5.0000e-04
# Epoch 38/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 2.0271 - main_output_accuracy: 0.5799 - main_output_loss: 1.7645 - tof_gate_loss: 0.2839 - val_loss: 1.7963 - val_main_output_accuracy: 0.6642 - val_main_output_loss: 1.5767 - val_tof_gate_loss: 0.1177 - learning_rate: 5.0000e-04
# Epoch 39/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 2.0990 - main_output_accuracy: 0.5708 - main_output_loss: 1.8327 - tof_gate_loss: 0.3150 - val_loss: 1.8697 - val_main_output_accuracy: 0.6189 - val_main_output_loss: 1.6461 - val_tof_gate_loss: 0.0895 - learning_rate: 5.0000e-04
# Epoch 40/160
# 102/112 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2.0247 - main_output_accuracy: 0.5835 - main_output_loss: 1.7673 - tof_gate_loss: 0.2728
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 2.0263 - main_output_accuracy: 0.5832 - main_output_loss: 1.7686 - tof_gate_loss: 0.2741 - val_loss: 1.6051 - val_main_output_accuracy: 0.6765 - val_main_output_loss: 1.3920 - val_tof_gate_loss: 0.0526 - learning_rate: 5.0000e-04
# Epoch 41/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 2.0357 - main_output_accuracy: 0.5819 - main_output_loss: 1.7793 - tof_gate_loss: 0.2991 - val_loss: 1.7243 - val_main_output_accuracy: 0.6728 - val_main_output_loss: 1.5305 - val_tof_gate_loss: 0.0739 - learning_rate: 2.5000e-04
# Epoch 42/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.9693 - main_output_accuracy: 0.6003 - main_output_loss: 1.7195 - tof_gate_loss: 0.2848 - val_loss: 1.6088 - val_main_output_accuracy: 0.6936 - val_main_output_loss: 1.4077 - val_tof_gate_loss: 0.0673 - learning_rate: 2.5000e-04
# Epoch 43/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.9806 - main_output_accuracy: 0.5982 - main_output_loss: 1.7381 - tof_gate_loss: 0.2908 - val_loss: 1.7074 - val_main_output_accuracy: 0.6801 - val_main_output_loss: 1.5231 - val_tof_gate_loss: 0.0662 - learning_rate: 2.5000e-04
# Epoch 44/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - loss: 1.8852 - main_output_accuracy: 0.6264 - main_output_loss: 1.6553 - tof_gate_loss: 0.2774 - val_loss: 1.8298 - val_main_output_accuracy: 0.6630 - val_main_output_loss: 1.6391 - val_tof_gate_loss: 0.0827 - learning_rate: 2.5000e-04
# Epoch 45/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 1.8390 - main_output_accuracy: 0.6340 - main_output_loss: 1.6113 - tof_gate_loss: 0.2639 - val_loss: 1.6234 - val_main_output_accuracy: 0.6654 - val_main_output_loss: 1.4321 - val_tof_gate_loss: 0.0643 - learning_rate: 2.5000e-04
# Epoch 46/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.9337 - main_output_accuracy: 0.6215 - main_output_loss: 1.7061 - tof_gate_loss: 0.2723 - val_loss: 1.7450 - val_main_output_accuracy: 0.6875 - val_main_output_loss: 1.5512 - val_tof_gate_loss: 0.0948 - learning_rate: 2.5000e-04
# Epoch 47/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.8956 - main_output_accuracy: 0.6280 - main_output_loss: 1.6708 - tof_gate_loss: 0.2832 - val_loss: 1.7612 - val_main_output_accuracy: 0.6458 - val_main_output_loss: 1.5734 - val_tof_gate_loss: 0.0679 - learning_rate: 2.5000e-04
# Epoch 48/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.9046 - main_output_accuracy: 0.6295 - main_output_loss: 1.6822 - tof_gate_loss: 0.2702 - val_loss: 1.6344 - val_main_output_accuracy: 0.6961 - val_main_output_loss: 1.4490 - val_tof_gate_loss: 0.0622 - learning_rate: 2.5000e-04
# Epoch 49/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.8985 - main_output_accuracy: 0.6205 - main_output_loss: 1.6758 - tof_gate_loss: 0.2798 - val_loss: 1.5496 - val_main_output_accuracy: 0.7108 - val_main_output_loss: 1.3726 - val_tof_gate_loss: 0.0634 - learning_rate: 2.5000e-04
# Epoch 50/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 1.8876 - main_output_accuracy: 0.6397 - main_output_loss: 1.6690 - tof_gate_loss: 0.2706 - val_loss: 1.7745 - val_main_output_accuracy: 0.6667 - val_main_output_loss: 1.5928 - val_tof_gate_loss: 0.0640 - learning_rate: 2.5000e-04
# Epoch 51/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 1.8567 - main_output_accuracy: 0.6388 - main_output_loss: 1.6405 - tof_gate_loss: 0.2688 - val_loss: 1.7119 - val_main_output_accuracy: 0.7010 - val_main_output_loss: 1.5471 - val_tof_gate_loss: 0.0549 - learning_rate: 2.5000e-04
# Epoch 52/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 1.9024 - main_output_accuracy: 0.6350 - main_output_loss: 1.6873 - tof_gate_loss: 0.2790 - val_loss: 1.7084 - val_main_output_accuracy: 0.6618 - val_main_output_loss: 1.5424 - val_tof_gate_loss: 0.0677 - learning_rate: 2.5000e-04
# Epoch 53/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.9386 - main_output_accuracy: 0.6280 - main_output_loss: 1.7169 - tof_gate_loss: 0.3056 - val_loss: 1.7490 - val_main_output_accuracy: 0.6581 - val_main_output_loss: 1.5625 - val_tof_gate_loss: 0.0931 - learning_rate: 2.5000e-04
# Epoch 54/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.8994 - main_output_accuracy: 0.6377 - main_output_loss: 1.6970 - tof_gate_loss: 0.2916 - val_loss: 1.6302 - val_main_output_accuracy: 0.7108 - val_main_output_loss: 1.4644 - val_tof_gate_loss: 0.0587 - learning_rate: 2.5000e-04
# Epoch 55/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.9179 - main_output_accuracy: 0.6484 - main_output_loss: 1.7045 - tof_gate_loss: 0.2777 - val_loss: 1.6392 - val_main_output_accuracy: 0.7145 - val_main_output_loss: 1.4669 - val_tof_gate_loss: 0.0715 - learning_rate: 2.5000e-04
# Epoch 56/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.8779 - main_output_accuracy: 0.6203 - main_output_loss: 1.6678 - tof_gate_loss: 0.2712 - val_loss: 1.5605 - val_main_output_accuracy: 0.7034 - val_main_output_loss: 1.3926 - val_tof_gate_loss: 0.0583 - learning_rate: 2.5000e-04
# Epoch 57/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.8833 - main_output_accuracy: 0.6461 - main_output_loss: 1.6748 - tof_gate_loss: 0.2683 - val_loss: 1.6400 - val_main_output_accuracy: 0.7218 - val_main_output_loss: 1.4671 - val_tof_gate_loss: 0.0680 - learning_rate: 2.5000e-04
# Epoch 58/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.8675 - main_output_accuracy: 0.6465 - main_output_loss: 1.6521 - tof_gate_loss: 0.2847 - val_loss: 1.7642 - val_main_output_accuracy: 0.6703 - val_main_output_loss: 1.6026 - val_tof_gate_loss: 0.0744 - learning_rate: 2.5000e-04
# Epoch 59/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.9059 - main_output_accuracy: 0.6412 - main_output_loss: 1.6936 - tof_gate_loss: 0.2840 - val_loss: 1.7884 - val_main_output_accuracy: 0.6703 - val_main_output_loss: 1.6116 - val_tof_gate_loss: 0.0873 - learning_rate: 2.5000e-04
# Epoch 60/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.7913 - main_output_accuracy: 0.6677 - main_output_loss: 1.5867 - tof_gate_loss: 0.2528 - val_loss: 1.6674 - val_main_output_accuracy: 0.6863 - val_main_output_loss: 1.4989 - val_tof_gate_loss: 0.0475 - learning_rate: 2.5000e-04
# Epoch 61/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.8482 - main_output_accuracy: 0.6433 - main_output_loss: 1.6369 - tof_gate_loss: 0.2802 - val_loss: 1.6656 - val_main_output_accuracy: 0.6900 - val_main_output_loss: 1.5013 - val_tof_gate_loss: 0.0558 - learning_rate: 2.5000e-04
# Epoch 62/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.8332 - main_output_accuracy: 0.6545 - main_output_loss: 1.6227 - tof_gate_loss: 0.2611 - val_loss: 1.6895 - val_main_output_accuracy: 0.6985 - val_main_output_loss: 1.5194 - val_tof_gate_loss: 0.0601 - learning_rate: 2.5000e-04
# Epoch 63/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.8322 - main_output_accuracy: 0.6455 - main_output_loss: 1.6266 - tof_gate_loss: 0.2710 - val_loss: 1.6188 - val_main_output_accuracy: 0.7267 - val_main_output_loss: 1.4639 - val_tof_gate_loss: 0.0616 - learning_rate: 2.5000e-04
# Epoch 64/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 1.8362 - main_output_accuracy: 0.6480 - main_output_loss: 1.6316 - tof_gate_loss: 0.2580 - val_loss: 1.5663 - val_main_output_accuracy: 0.7206 - val_main_output_loss: 1.3980 - val_tof_gate_loss: 0.0584 - learning_rate: 2.5000e-04
# Epoch 65/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.8051 - main_output_accuracy: 0.6635 - main_output_loss: 1.5984 - tof_gate_loss: 0.2608 - val_loss: 1.7828 - val_main_output_accuracy: 0.6642 - val_main_output_loss: 1.6288 - val_tof_gate_loss: 0.0617 - learning_rate: 2.5000e-04
# Epoch 66/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.8534 - main_output_accuracy: 0.6655 - main_output_loss: 1.6447 - tof_gate_loss: 0.2805 - val_loss: 1.6400 - val_main_output_accuracy: 0.6998 - val_main_output_loss: 1.4730 - val_tof_gate_loss: 0.0563 - learning_rate: 2.5000e-04
# Epoch 67/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7302 - main_output_accuracy: 0.6871 - main_output_loss: 1.5275 - tof_gate_loss: 0.2580 - val_loss: 1.6748 - val_main_output_accuracy: 0.6740 - val_main_output_loss: 1.5190 - val_tof_gate_loss: 0.0663 - learning_rate: 2.5000e-04
# Epoch 68/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.8104 - main_output_accuracy: 0.6657 - main_output_loss: 1.6025 - tof_gate_loss: 0.2655 - val_loss: 1.7358 - val_main_output_accuracy: 0.6887 - val_main_output_loss: 1.5639 - val_tof_gate_loss: 0.0586 - learning_rate: 2.5000e-04
# Epoch 69/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 114ms/step - loss: 1.8054 - main_output_accuracy: 0.6696 - main_output_loss: 1.5974 - tof_gate_loss: 0.2807 - val_loss: 1.7021 - val_main_output_accuracy: 0.6728 - val_main_output_loss: 1.5327 - val_tof_gate_loss: 0.0789 - learning_rate: 2.5000e-04
# Epoch 70/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.9347 - main_output_accuracy: 0.6381 - main_output_loss: 1.7210 - tof_gate_loss: 0.2975 - val_loss: 1.7239 - val_main_output_accuracy: 0.6691 - val_main_output_loss: 1.5593 - val_tof_gate_loss: 0.0663 - learning_rate: 2.5000e-04
# Epoch 71/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.7283 - main_output_accuracy: 0.6852 - main_output_loss: 1.5251 - tof_gate_loss: 0.2585
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.7288 - main_output_accuracy: 0.6850 - main_output_loss: 1.5256 - tof_gate_loss: 0.2586 - val_loss: 1.7249 - val_main_output_accuracy: 0.6789 - val_main_output_loss: 1.5540 - val_tof_gate_loss: 0.0805 - learning_rate: 2.5000e-04
# Epoch 72/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.8375 - main_output_accuracy: 0.6670 - main_output_loss: 1.6266 - tof_gate_loss: 0.2891 - val_loss: 1.5955 - val_main_output_accuracy: 0.7279 - val_main_output_loss: 1.4276 - val_tof_gate_loss: 0.0660 - learning_rate: 1.2500e-04
# Epoch 73/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.8688 - main_output_accuracy: 0.6314 - main_output_loss: 1.6566 - tof_gate_loss: 0.3091 - val_loss: 1.6868 - val_main_output_accuracy: 0.7034 - val_main_output_loss: 1.5143 - val_tof_gate_loss: 0.0876 - learning_rate: 1.2500e-04
# Epoch 74/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.8184 - main_output_accuracy: 0.6667 - main_output_loss: 1.6129 - tof_gate_loss: 0.2845 - val_loss: 1.5812 - val_main_output_accuracy: 0.7267 - val_main_output_loss: 1.4258 - val_tof_gate_loss: 0.0548 - learning_rate: 1.2500e-04
# Epoch 75/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7910 - main_output_accuracy: 0.6617 - main_output_loss: 1.5874 - tof_gate_loss: 0.2768 - val_loss: 1.6044 - val_main_output_accuracy: 0.6985 - val_main_output_loss: 1.4423 - val_tof_gate_loss: 0.0687 - learning_rate: 1.2500e-04
# Epoch 76/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.7398 - main_output_accuracy: 0.6978 - main_output_loss: 1.5433 - tof_gate_loss: 0.2591 - val_loss: 1.4350 - val_main_output_accuracy: 0.7451 - val_main_output_loss: 1.2772 - val_tof_gate_loss: 0.0588 - learning_rate: 1.2500e-04
# Epoch 77/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7667 - main_output_accuracy: 0.6967 - main_output_loss: 1.5668 - tof_gate_loss: 0.2838 - val_loss: 1.4926 - val_main_output_accuracy: 0.7341 - val_main_output_loss: 1.3339 - val_tof_gate_loss: 0.0592 - learning_rate: 1.2500e-04
# Epoch 78/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.7060 - main_output_accuracy: 0.7163 - main_output_loss: 1.5116 - tof_gate_loss: 0.2545 - val_loss: 1.6152 - val_main_output_accuracy: 0.6900 - val_main_output_loss: 1.4552 - val_tof_gate_loss: 0.0661 - learning_rate: 1.2500e-04
# Epoch 79/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.7460 - main_output_accuracy: 0.6920 - main_output_loss: 1.5512 - tof_gate_loss: 0.2649 - val_loss: 1.5163 - val_main_output_accuracy: 0.7047 - val_main_output_loss: 1.3613 - val_tof_gate_loss: 0.0602 - learning_rate: 1.2500e-04
# Epoch 80/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.7672 - main_output_accuracy: 0.6918 - main_output_loss: 1.5829 - tof_gate_loss: 0.2647 - val_loss: 1.5395 - val_main_output_accuracy: 0.7488 - val_main_output_loss: 1.3808 - val_tof_gate_loss: 0.0684 - learning_rate: 1.2500e-04
# Epoch 81/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 120ms/step - loss: 1.6736 - main_output_accuracy: 0.7204 - main_output_loss: 1.4828 - tof_gate_loss: 0.2627 - val_loss: 1.4785 - val_main_output_accuracy: 0.7341 - val_main_output_loss: 1.3228 - val_tof_gate_loss: 0.0621 - learning_rate: 1.2500e-04
# Epoch 82/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.6592 - main_output_accuracy: 0.7076 - main_output_loss: 1.4661 - tof_gate_loss: 0.2630 - val_loss: 1.6456 - val_main_output_accuracy: 0.7022 - val_main_output_loss: 1.4897 - val_tof_gate_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 83/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.7307 - main_output_accuracy: 0.6868 - main_output_loss: 1.5395 - tof_gate_loss: 0.2629 - val_loss: 1.6768 - val_main_output_accuracy: 0.7034 - val_main_output_loss: 1.5198 - val_tof_gate_loss: 0.0670 - learning_rate: 1.2500e-04
# Epoch 84/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7580 - main_output_accuracy: 0.6910 - main_output_loss: 1.5682 - tof_gate_loss: 0.2805 - val_loss: 1.6120 - val_main_output_accuracy: 0.7022 - val_main_output_loss: 1.4738 - val_tof_gate_loss: 0.0674 - learning_rate: 1.2500e-04
# Epoch 85/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.7390 - main_output_accuracy: 0.6994 - main_output_loss: 1.5481 - tof_gate_loss: 0.2724 - val_loss: 1.6159 - val_main_output_accuracy: 0.6949 - val_main_output_loss: 1.4736 - val_tof_gate_loss: 0.0684 - learning_rate: 1.2500e-04
# Epoch 86/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.7099 - main_output_accuracy: 0.7010 - main_output_loss: 1.5222 - tof_gate_loss: 0.2609 - val_loss: 1.6317 - val_main_output_accuracy: 0.7120 - val_main_output_loss: 1.4789 - val_tof_gate_loss: 0.0715 - learning_rate: 1.2500e-04
# Epoch 87/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.7317 - main_output_accuracy: 0.6860 - main_output_loss: 1.5423 - tof_gate_loss: 0.2778 - val_loss: 1.8408 - val_main_output_accuracy: 0.6471 - val_main_output_loss: 1.6964 - val_tof_gate_loss: 0.0793 - learning_rate: 1.2500e-04
# Epoch 88/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.8062 - main_output_accuracy: 0.6700 - main_output_loss: 1.6142 - tof_gate_loss: 0.2865
# Epoch 88: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.8055 - main_output_accuracy: 0.6702 - main_output_loss: 1.6135 - tof_gate_loss: 0.2863 - val_loss: 1.4418 - val_main_output_accuracy: 0.7439 - val_main_output_loss: 1.2956 - val_tof_gate_loss: 0.0535 - learning_rate: 1.2500e-04
# Epoch 89/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.7662 - main_output_accuracy: 0.6905 - main_output_loss: 1.5788 - tof_gate_loss: 0.2966 - val_loss: 1.6755 - val_main_output_accuracy: 0.7279 - val_main_output_loss: 1.5379 - val_tof_gate_loss: 0.0684 - learning_rate: 6.2500e-05
# Epoch 90/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 1.7532 - main_output_accuracy: 0.7264 - main_output_loss: 1.5775 - tof_gate_loss: 0.2849 - val_loss: 1.5747 - val_main_output_accuracy: 0.7071 - val_main_output_loss: 1.4250 - val_tof_gate_loss: 0.0631 - learning_rate: 6.2500e-05
# Epoch 91/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.6288 - main_output_accuracy: 0.7383 - main_output_loss: 1.4479 - tof_gate_loss: 0.2468 - val_loss: 1.5399 - val_main_output_accuracy: 0.7108 - val_main_output_loss: 1.3928 - val_tof_gate_loss: 0.0548 - learning_rate: 6.2500e-05
# Epoch 92/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - loss: 1.6792 - main_output_accuracy: 0.7138 - main_output_loss: 1.4818 - tof_gate_loss: 0.2612 - val_loss: 1.5371 - val_main_output_accuracy: 0.7255 - val_main_output_loss: 1.4021 - val_tof_gate_loss: 0.0523 - learning_rate: 6.2500e-05
# Epoch 93/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.7268 - main_output_accuracy: 0.7113 - main_output_loss: 1.5398 - tof_gate_loss: 0.2801 - val_loss: 1.6071 - val_main_output_accuracy: 0.7304 - val_main_output_loss: 1.4587 - val_tof_gate_loss: 0.0615 - learning_rate: 6.2500e-05
# Epoch 94/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.8566 - main_output_accuracy: 0.6879 - main_output_loss: 1.6678 - tof_gate_loss: 0.3129 - val_loss: 1.6769 - val_main_output_accuracy: 0.7022 - val_main_output_loss: 1.5305 - val_tof_gate_loss: 0.0678 - learning_rate: 6.2500e-05
# Epoch 95/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.6480 - main_output_accuracy: 0.7412 - main_output_loss: 1.4735 - tof_gate_loss: 0.2617 - val_loss: 1.5302 - val_main_output_accuracy: 0.7194 - val_main_output_loss: 1.3857 - val_tof_gate_loss: 0.0627 - learning_rate: 6.2500e-05
# Epoch 96/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.6932 - main_output_accuracy: 0.7325 - main_output_loss: 1.5095 - tof_gate_loss: 0.2724 - val_loss: 1.5496 - val_main_output_accuracy: 0.7230 - val_main_output_loss: 1.4064 - val_tof_gate_loss: 0.0647 - learning_rate: 6.2500e-05
# Epoch 97/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.6109 - main_output_accuracy: 0.7482 - main_output_loss: 1.4319 - tof_gate_loss: 0.2557
# Epoch 97: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6113 - main_output_accuracy: 0.7481 - main_output_loss: 1.4322 - tof_gate_loss: 0.2558 - val_loss: 1.5553 - val_main_output_accuracy: 0.7390 - val_main_output_loss: 1.4119 - val_tof_gate_loss: 0.0621 - learning_rate: 6.2500e-05
# Epoch 98/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.7319 - main_output_accuracy: 0.7188 - main_output_loss: 1.5539 - tof_gate_loss: 0.2723 - val_loss: 1.5705 - val_main_output_accuracy: 0.7120 - val_main_output_loss: 1.4411 - val_tof_gate_loss: 0.0652 - learning_rate: 3.1250e-05
# Epoch 99/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6312 - main_output_accuracy: 0.7338 - main_output_loss: 1.4575 - tof_gate_loss: 0.2516 - val_loss: 1.5980 - val_main_output_accuracy: 0.7218 - val_main_output_loss: 1.4512 - val_tof_gate_loss: 0.0635 - learning_rate: 3.1250e-05
# Epoch 100/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.6328 - main_output_accuracy: 0.7303 - main_output_loss: 1.4561 - tof_gate_loss: 0.2616 - val_loss: 1.5996 - val_main_output_accuracy: 0.6801 - val_main_output_loss: 1.4677 - val_tof_gate_loss: 0.0661 - learning_rate: 3.1250e-05
# Epoch 101/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7189 - main_output_accuracy: 0.7341 - main_output_loss: 1.5353 - tof_gate_loss: 0.2845 - val_loss: 1.5067 - val_main_output_accuracy: 0.7267 - val_main_output_loss: 1.3794 - val_tof_gate_loss: 0.0614 - learning_rate: 3.1250e-05
# Epoch 102/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6442 - main_output_accuracy: 0.7339 - main_output_loss: 1.4605 - tof_gate_loss: 0.2667 - val_loss: 1.5142 - val_main_output_accuracy: 0.7414 - val_main_output_loss: 1.3751 - val_tof_gate_loss: 0.0583 - learning_rate: 3.1250e-05
# Epoch 103/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.6349 - main_output_accuracy: 0.7407 - main_output_loss: 1.4580 - tof_gate_loss: 0.2643 - val_loss: 1.5421 - val_main_output_accuracy: 0.7365 - val_main_output_loss: 1.3996 - val_tof_gate_loss: 0.0575 - learning_rate: 3.1250e-05
# Epoch 104/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.7601 - main_output_accuracy: 0.7212 - main_output_loss: 1.5734 - tof_gate_loss: 0.3072 - val_loss: 1.5958 - val_main_output_accuracy: 0.7157 - val_main_output_loss: 1.4520 - val_tof_gate_loss: 0.0646 - learning_rate: 3.1250e-05
# Epoch 105/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.7233 - main_output_accuracy: 0.7219 - main_output_loss: 1.5506 - tof_gate_loss: 0.2866 - val_loss: 1.6188 - val_main_output_accuracy: 0.6985 - val_main_output_loss: 1.4739 - val_tof_gate_loss: 0.0697 - learning_rate: 3.1250e-05
# Epoch 106/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.6320 - main_output_accuracy: 0.7260 - main_output_loss: 1.4514 - tof_gate_loss: 0.2678
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.6320 - main_output_accuracy: 0.7261 - main_output_loss: 1.4514 - tof_gate_loss: 0.2677 - val_loss: 1.4003 - val_main_output_accuracy: 0.7365 - val_main_output_loss: 1.2632 - val_tof_gate_loss: 0.0524 - learning_rate: 3.1250e-05
# Epoch 107/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.6774 - main_output_accuracy: 0.7448 - main_output_loss: 1.4977 - tof_gate_loss: 0.2789 - val_loss: 1.5767 - val_main_output_accuracy: 0.7279 - val_main_output_loss: 1.4535 - val_tof_gate_loss: 0.0638 - learning_rate: 1.5625e-05
# Epoch 108/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7278 - main_output_accuracy: 0.7253 - main_output_loss: 1.5447 - tof_gate_loss: 0.2889 - val_loss: 1.6171 - val_main_output_accuracy: 0.7181 - val_main_output_loss: 1.4720 - val_tof_gate_loss: 0.0640 - learning_rate: 1.5625e-05
# Epoch 109/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 1.7148 - main_output_accuracy: 0.7331 - main_output_loss: 1.5412 - tof_gate_loss: 0.2839 - val_loss: 1.5838 - val_main_output_accuracy: 0.7108 - val_main_output_loss: 1.4487 - val_tof_gate_loss: 0.0614 - learning_rate: 1.5625e-05
# Epoch 110/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.6918 - main_output_accuracy: 0.7080 - main_output_loss: 1.5126 - tof_gate_loss: 0.2785 - val_loss: 1.4777 - val_main_output_accuracy: 0.7512 - val_main_output_loss: 1.3391 - val_tof_gate_loss: 0.0565 - learning_rate: 1.5625e-05
# Epoch 111/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 1.6384 - main_output_accuracy: 0.7422 - main_output_loss: 1.4602 - tof_gate_loss: 0.2652 - val_loss: 1.5280 - val_main_output_accuracy: 0.7279 - val_main_output_loss: 1.3970 - val_tof_gate_loss: 0.0598 - learning_rate: 1.5625e-05
# Epoch 112/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.5235 - main_output_accuracy: 0.7710 - main_output_loss: 1.3529 - tof_gate_loss: 0.2366 - val_loss: 1.5394 - val_main_output_accuracy: 0.7377 - val_main_output_loss: 1.3978 - val_tof_gate_loss: 0.0583 - learning_rate: 1.5625e-05
# Epoch 113/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.5736 - main_output_accuracy: 0.7576 - main_output_loss: 1.4035 - tof_gate_loss: 0.2554 - val_loss: 1.4041 - val_main_output_accuracy: 0.7463 - val_main_output_loss: 1.2682 - val_tof_gate_loss: 0.0519 - learning_rate: 1.5625e-05
# Epoch 114/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.6156 - main_output_accuracy: 0.7456 - main_output_loss: 1.4414 - tof_gate_loss: 0.2599 - val_loss: 1.4816 - val_main_output_accuracy: 0.7255 - val_main_output_loss: 1.3432 - val_tof_gate_loss: 0.0573 - learning_rate: 1.5625e-05
# Epoch 115/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.7281 - main_output_accuracy: 0.7233 - main_output_loss: 1.5511 - tof_gate_loss: 0.2753 - val_loss: 1.6438 - val_main_output_accuracy: 0.7010 - val_main_output_loss: 1.4983 - val_tof_gate_loss: 0.0655 - learning_rate: 1.5625e-05
# Epoch 116/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6297 - main_output_accuracy: 0.7399 - main_output_loss: 1.4578 - tof_gate_loss: 0.2733 - val_loss: 1.6122 - val_main_output_accuracy: 0.7181 - val_main_output_loss: 1.4824 - val_tof_gate_loss: 0.0607 - learning_rate: 1.5625e-05
# Epoch 117/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.6115 - main_output_accuracy: 0.7519 - main_output_loss: 1.4364 - tof_gate_loss: 0.2700 - val_loss: 1.5016 - val_main_output_accuracy: 0.7365 - val_main_output_loss: 1.3760 - val_tof_gate_loss: 0.0556 - learning_rate: 1.5625e-05
# Epoch 118/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.4942 - main_output_accuracy: 0.7817 - main_output_loss: 1.3292 - tof_gate_loss: 0.2413
# Epoch 118: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.4947 - main_output_accuracy: 0.7815 - main_output_loss: 1.3297 - tof_gate_loss: 0.2414 - val_loss: 1.4934 - val_main_output_accuracy: 0.7377 - val_main_output_loss: 1.3562 - val_tof_gate_loss: 0.0565 - learning_rate: 1.5625e-05
# Epoch 119/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.5716 - main_output_accuracy: 0.7726 - main_output_loss: 1.4007 - tof_gate_loss: 0.2460 - val_loss: 1.5870 - val_main_output_accuracy: 0.7108 - val_main_output_loss: 1.4467 - val_tof_gate_loss: 0.0599 - learning_rate: 7.8125e-06
# Epoch 120/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 1.7510 - main_output_accuracy: 0.7275 - main_output_loss: 1.5691 - tof_gate_loss: 0.2902 - val_loss: 1.4459 - val_main_output_accuracy: 0.7610 - val_main_output_loss: 1.3157 - val_tof_gate_loss: 0.0515 - learning_rate: 7.8125e-06
# Epoch 121/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.7197 - main_output_accuracy: 0.7182 - main_output_loss: 1.5457 - tof_gate_loss: 0.2929 - val_loss: 1.4246 - val_main_output_accuracy: 0.7463 - val_main_output_loss: 1.2923 - val_tof_gate_loss: 0.0521 - learning_rate: 7.8125e-06
# Epoch 122/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.6335 - main_output_accuracy: 0.7363 - main_output_loss: 1.4622 - tof_gate_loss: 0.2568 - val_loss: 1.5525 - val_main_output_accuracy: 0.7267 - val_main_output_loss: 1.4194 - val_tof_gate_loss: 0.0591 - learning_rate: 7.8125e-06
# Epoch 123/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 1.6526 - main_output_accuracy: 0.7369 - main_output_loss: 1.4733 - tof_gate_loss: 0.2868 - val_loss: 1.5591 - val_main_output_accuracy: 0.7120 - val_main_output_loss: 1.4189 - val_tof_gate_loss: 0.0577 - learning_rate: 7.8125e-06
# Epoch 124/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.6743 - main_output_accuracy: 0.7261 - main_output_loss: 1.4921 - tof_gate_loss: 0.2755 - val_loss: 1.6178 - val_main_output_accuracy: 0.6887 - val_main_output_loss: 1.4828 - val_tof_gate_loss: 0.0626 - learning_rate: 7.8125e-06
# Epoch 125/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 1.5793 - main_output_accuracy: 0.7468 - main_output_loss: 1.4080 - tof_gate_loss: 0.2521 - val_loss: 1.3451 - val_main_output_accuracy: 0.7586 - val_main_output_loss: 1.2145 - val_tof_gate_loss: 0.0488 - learning_rate: 7.8125e-06
# Epoch 126/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.6447 - main_output_accuracy: 0.7353 - main_output_loss: 1.4611 - tof_gate_loss: 0.2714 - val_loss: 1.4213 - val_main_output_accuracy: 0.7525 - val_main_output_loss: 1.2888 - val_tof_gate_loss: 0.0520 - learning_rate: 7.8125e-06
# Epoch 127/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 13s 112ms/step - loss: 1.6574 - main_output_accuracy: 0.7266 - main_output_loss: 1.4882 - tof_gate_loss: 0.2797 - val_loss: 1.4109 - val_main_output_accuracy: 0.7414 - val_main_output_loss: 1.2822 - val_tof_gate_loss: 0.0496 - learning_rate: 7.8125e-06
# Epoch 128/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 1.6039 - main_output_accuracy: 0.7510 - main_output_loss: 1.4320 - tof_gate_loss: 0.2578
# Epoch 128: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.6040 - main_output_accuracy: 0.7509 - main_output_loss: 1.4321 - tof_gate_loss: 0.2579 - val_loss: 1.5507 - val_main_output_accuracy: 0.7132 - val_main_output_loss: 1.4131 - val_tof_gate_loss: 0.0606 - learning_rate: 7.8125e-06
# Epoch 129/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.5618 - main_output_accuracy: 0.7562 - main_output_loss: 1.3910 - tof_gate_loss: 0.2591 - val_loss: 1.5027 - val_main_output_accuracy: 0.7561 - val_main_output_loss: 1.3689 - val_tof_gate_loss: 0.0546 - learning_rate: 3.9063e-06
# Epoch 130/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.7019 - main_output_accuracy: 0.7411 - main_output_loss: 1.5142 - tof_gate_loss: 0.2851 - val_loss: 1.5023 - val_main_output_accuracy: 0.7500 - val_main_output_loss: 1.3676 - val_tof_gate_loss: 0.0543 - learning_rate: 3.9063e-06
# Epoch 131/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.6290 - main_output_accuracy: 0.7506 - main_output_loss: 1.4551 - tof_gate_loss: 0.2597 - val_loss: 1.6210 - val_main_output_accuracy: 0.6973 - val_main_output_loss: 1.4998 - val_tof_gate_loss: 0.0636 - learning_rate: 3.9063e-06
# Epoch 132/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6159 - main_output_accuracy: 0.7344 - main_output_loss: 1.4413 - tof_gate_loss: 0.2666 - val_loss: 1.5828 - val_main_output_accuracy: 0.7169 - val_main_output_loss: 1.4555 - val_tof_gate_loss: 0.0600 - learning_rate: 3.9063e-06
# Epoch 133/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.5325 - main_output_accuracy: 0.7660 - main_output_loss: 1.3748 - tof_gate_loss: 0.2575 - val_loss: 1.4360 - val_main_output_accuracy: 0.7328 - val_main_output_loss: 1.3005 - val_tof_gate_loss: 0.0508 - learning_rate: 3.9063e-06
# Epoch 134/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 1.4988 - main_output_accuracy: 0.7665 - main_output_loss: 1.3317 - tof_gate_loss: 0.2453 - val_loss: 1.5307 - val_main_output_accuracy: 0.7525 - val_main_output_loss: 1.3918 - val_tof_gate_loss: 0.0578 - learning_rate: 3.9063e-06
# Epoch 135/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.6863 - main_output_accuracy: 0.7427 - main_output_loss: 1.5080 - tof_gate_loss: 0.2896 - val_loss: 1.5337 - val_main_output_accuracy: 0.7402 - val_main_output_loss: 1.3986 - val_tof_gate_loss: 0.0571 - learning_rate: 3.9063e-06
# Epoch 136/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - loss: 1.5650 - main_output_accuracy: 0.7571 - main_output_loss: 1.4005 - tof_gate_loss: 0.2415 - val_loss: 1.4814 - val_main_output_accuracy: 0.7365 - val_main_output_loss: 1.3480 - val_tof_gate_loss: 0.0543 - learning_rate: 3.9063e-06
# Epoch 137/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.7321 - main_output_accuracy: 0.7241 - main_output_loss: 1.5517 - tof_gate_loss: 0.2853
# Epoch 137: ReduceLROnPlateau reducing learning rate to 3e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 1.7314 - main_output_accuracy: 0.7243 - main_output_loss: 1.5511 - tof_gate_loss: 0.2852 - val_loss: 1.5698 - val_main_output_accuracy: 0.7341 - val_main_output_loss: 1.4359 - val_tof_gate_loss: 0.0585 - learning_rate: 3.9063e-06
# Epoch 138/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.5821 - main_output_accuracy: 0.7370 - main_output_loss: 1.4093 - tof_gate_loss: 0.2581 - val_loss: 1.5556 - val_main_output_accuracy: 0.7059 - val_main_output_loss: 1.4275 - val_tof_gate_loss: 0.0615 - learning_rate: 3.0000e-06
# Epoch 139/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.7120 - main_output_accuracy: 0.7247 - main_output_loss: 1.5326 - tof_gate_loss: 0.2979 - val_loss: 1.5628 - val_main_output_accuracy: 0.7488 - val_main_output_loss: 1.4259 - val_tof_gate_loss: 0.0599 - learning_rate: 3.0000e-06
# Epoch 140/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.5613 - main_output_accuracy: 0.7672 - main_output_loss: 1.3914 - tof_gate_loss: 0.2547 - val_loss: 1.5331 - val_main_output_accuracy: 0.7365 - val_main_output_loss: 1.4050 - val_tof_gate_loss: 0.0599 - learning_rate: 3.0000e-06
# Epoch 141/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 1.6704 - main_output_accuracy: 0.7271 - main_output_loss: 1.4953 - tof_gate_loss: 0.2755 - val_loss: 1.5127 - val_main_output_accuracy: 0.7512 - val_main_output_loss: 1.3784 - val_tof_gate_loss: 0.0570 - learning_rate: 3.0000e-06
# Epoch 142/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.5581 - main_output_accuracy: 0.7607 - main_output_loss: 1.3858 - tof_gate_loss: 0.2551 - val_loss: 1.5739 - val_main_output_accuracy: 0.7304 - val_main_output_loss: 1.4370 - val_tof_gate_loss: 0.0588 - learning_rate: 3.0000e-06
# Epoch 143/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.7154 - main_output_accuracy: 0.7209 - main_output_loss: 1.5364 - tof_gate_loss: 0.2935 - val_loss: 1.4892 - val_main_output_accuracy: 0.7488 - val_main_output_loss: 1.3602 - val_tof_gate_loss: 0.0550 - learning_rate: 3.0000e-06
# Epoch 144/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6032 - main_output_accuracy: 0.7278 - main_output_loss: 1.4289 - tof_gate_loss: 0.2706 - val_loss: 1.5359 - val_main_output_accuracy: 0.7267 - val_main_output_loss: 1.4021 - val_tof_gate_loss: 0.0580 - learning_rate: 3.0000e-06
# Epoch 145/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - loss: 1.7026 - main_output_accuracy: 0.7296 - main_output_loss: 1.5240 - tof_gate_loss: 0.2840 - val_loss: 1.4071 - val_main_output_accuracy: 0.7598 - val_main_output_loss: 1.2689 - val_tof_gate_loss: 0.0500 - learning_rate: 3.0000e-06
# Epoch 146/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 1.5547 - main_output_accuracy: 0.7622 - main_output_loss: 1.3828 - tof_gate_loss: 0.2481 - val_loss: 1.4086 - val_main_output_accuracy: 0.7463 - val_main_output_loss: 1.2740 - val_tof_gate_loss: 0.0501 - learning_rate: 3.0000e-06
# Epoch 147/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.6652 - main_output_accuracy: 0.7312 - main_output_loss: 1.4903 - tof_gate_loss: 0.2702 - val_loss: 1.5605 - val_main_output_accuracy: 0.7071 - val_main_output_loss: 1.4319 - val_tof_gate_loss: 0.0611 - learning_rate: 3.0000e-06
# Epoch 148/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 1.6874 - main_output_accuracy: 0.7439 - main_output_loss: 1.5118 - tof_gate_loss: 0.2752 - val_loss: 1.7256 - val_main_output_accuracy: 0.6752 - val_main_output_loss: 1.5873 - val_tof_gate_loss: 0.0693 - learning_rate: 3.0000e-06
# Epoch 149/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - loss: 1.6341 - main_output_accuracy: 0.7413 - main_output_loss: 1.4619 - tof_gate_loss: 0.2644 - val_loss: 1.4049 - val_main_output_accuracy: 0.7610 - val_main_output_loss: 1.2749 - val_tof_gate_loss: 0.0494 - learning_rate: 3.0000e-06
# Epoch 150/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.6396 - main_output_accuracy: 0.7511 - main_output_loss: 1.4670 - tof_gate_loss: 0.2644 - val_loss: 1.5095 - val_main_output_accuracy: 0.7426 - val_main_output_loss: 1.3867 - val_tof_gate_loss: 0.0543 - learning_rate: 3.0000e-06
# Epoch 151/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - loss: 1.5950 - main_output_accuracy: 0.7550 - main_output_loss: 1.4195 - tof_gate_loss: 0.2708 - val_loss: 1.6054 - val_main_output_accuracy: 0.7218 - val_main_output_loss: 1.4674 - val_tof_gate_loss: 0.0605 - learning_rate: 3.0000e-06
# Epoch 152/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 1.5795 - main_output_accuracy: 0.7473 - main_output_loss: 1.4037 - tof_gate_loss: 0.2742 - val_loss: 1.5643 - val_main_output_accuracy: 0.7292 - val_main_output_loss: 1.4292 - val_tof_gate_loss: 0.0563 - learning_rate: 3.0000e-06
# Epoch 153/160
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - loss: 1.5597 - main_output_accuracy: 0.7646 - main_output_loss: 1.3896 - tof_gate_loss: 0.2530 - val_loss: 1.5740 - val_main_output_accuracy: 0.7426 - val_main_output_loss: 1.4369 - val_tof_gate_loss: 0.0586 - learning_rate: 3.0000e-06
# Epoch 154/160
# ...
# Epoch 62/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 129ms/step - loss: 1.7475 - main_output_accuracy: 0.6903 - main_output_loss: 1.5478 - tof_gate_loss: 0.2730 - val_loss: 1.6882 - val_main_output_accuracy: 0.6742 - val_main_output_loss: 1.5192 - val_tof_gate_loss: 0.0577 - learning_rate: 6.2500e-05
# Epoch 63/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.8345 - main_output_accuracy: 0.6780 - main_output_loss: 1.6340 - tof_gate_loss: 0.2919 - val_loss: 1.6090 - val_main_output_accuracy: 0.6772 - val_main_output_loss: 1.4424 - val_tof_gate_loss: 0.0655 - learning_rate: 6.2500e-05
# Epoch 64/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.8737 - main_output_accuracy: 0.6615 - main_output_loss: 1.6712 - tof_gate_loss: 0.2903 - val_loss: 1.5252 - val_main_output_accuracy: 0.7027 - val_main_output_loss: 1.3717 - val_tof_gate_loss: 0.0559 - learning_rate: 6.2500e-05
# Epoch 65/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 129ms/step - loss: 1.8242 - main_output_accuracy: 0.6629 - main_output_loss: 1.6244 - tof_gate_loss: 0.2967 - val_loss: 1.7268 - val_main_output_accuracy: 0.6667 - val_main_output_loss: 1.5542 - val_tof_gate_loss: 0.0738 - learning_rate: 6.2500e-05
# Epoch 66/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - loss: 1.8050 - main_output_accuracy: 0.6821 - main_output_loss: 1.6079 - tof_gate_loss: 0.2810 - val_loss: 1.7112 - val_main_output_accuracy: 0.6802 - val_main_output_loss: 1.5369 - val_tof_gate_loss: 0.0680 - learning_rate: 6.2500e-05
# Epoch 67/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 127ms/step - loss: 1.8149 - main_output_accuracy: 0.6831 - main_output_loss: 1.6169 - tof_gate_loss: 0.2919 - val_loss: 1.5009 - val_main_output_accuracy: 0.7072 - val_main_output_loss: 1.3587 - val_tof_gate_loss: 0.0607 - learning_rate: 6.2500e-05
# Epoch 68/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.8305 - main_output_accuracy: 0.6760 - main_output_loss: 1.6338 - tof_gate_loss: 0.2896 - val_loss: 1.5206 - val_main_output_accuracy: 0.7252 - val_main_output_loss: 1.3646 - val_tof_gate_loss: 0.0611 - learning_rate: 6.2500e-05
# Epoch 69/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 127ms/step - loss: 1.8014 - main_output_accuracy: 0.6860 - main_output_loss: 1.6100 - tof_gate_loss: 0.2853 - val_loss: 1.6057 - val_main_output_accuracy: 0.6937 - val_main_output_loss: 1.4465 - val_tof_gate_loss: 0.0660 - learning_rate: 6.2500e-05
# Epoch 70/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.6849 - main_output_accuracy: 0.6959 - main_output_loss: 1.4964 - tof_gate_loss: 0.2574 - val_loss: 1.7444 - val_main_output_accuracy: 0.6502 - val_main_output_loss: 1.5794 - val_tof_gate_loss: 0.0743 - learning_rate: 6.2500e-05
# Epoch 71/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - loss: 1.7309 - main_output_accuracy: 0.6969 - main_output_loss: 1.5446 - tof_gate_loss: 0.2703 - val_loss: 1.6288 - val_main_output_accuracy: 0.6637 - val_main_output_loss: 1.5201 - val_tof_gate_loss: 0.0610 - learning_rate: 6.2500e-05
# Epoch 72/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.8014 - main_output_accuracy: 0.6967 - main_output_loss: 1.6079 - tof_gate_loss: 0.2902 - val_loss: 1.7374 - val_main_output_accuracy: 0.6171 - val_main_output_loss: 1.5679 - val_tof_gate_loss: 0.0629 - learning_rate: 6.2500e-05
# Epoch 73/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - loss: 1.6726 - main_output_accuracy: 0.7110 - main_output_loss: 1.4867 - tof_gate_loss: 0.2548 - val_loss: 1.6235 - val_main_output_accuracy: 0.6787 - val_main_output_loss: 1.4669 - val_tof_gate_loss: 0.0648 - learning_rate: 6.2500e-05
# Epoch 74/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.6965 - main_output_accuracy: 0.7075 - main_output_loss: 1.5093 - tof_gate_loss: 0.2642 - val_loss: 1.6216 - val_main_output_accuracy: 0.6937 - val_main_output_loss: 1.4591 - val_tof_gate_loss: 0.0610 - learning_rate: 6.2500e-05
# Epoch 75/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.5990 - main_output_accuracy: 0.7346 - main_output_loss: 1.4164 - tof_gate_loss: 0.2429 - val_loss: 1.7040 - val_main_output_accuracy: 0.6817 - val_main_output_loss: 1.6137 - val_tof_gate_loss: 0.0653 - learning_rate: 6.2500e-05
# Epoch 76/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.5870 - main_output_accuracy: 0.7241 - main_output_loss: 1.4035 - tof_gate_loss: 0.2507
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.5880 - main_output_accuracy: 0.7239 - main_output_loss: 1.4045 - tof_gate_loss: 0.2509 - val_loss: 1.8066 - val_main_output_accuracy: 0.6261 - val_main_output_loss: 1.6838 - val_tof_gate_loss: 0.0717 - learning_rate: 6.2500e-05
# Epoch 77/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - loss: 1.6628 - main_output_accuracy: 0.7259 - main_output_loss: 1.4820 - tof_gate_loss: 0.2555 - val_loss: 1.5562 - val_main_output_accuracy: 0.6937 - val_main_output_loss: 1.4355 - val_tof_gate_loss: 0.0571 - learning_rate: 3.1250e-05
# Epoch 78/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 129ms/step - loss: 1.7400 - main_output_accuracy: 0.7016 - main_output_loss: 1.5527 - tof_gate_loss: 0.2791 - val_loss: 1.6931 - val_main_output_accuracy: 0.6847 - val_main_output_loss: 1.5391 - val_tof_gate_loss: 0.0637 - learning_rate: 3.1250e-05
# Epoch 79/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.8337 - main_output_accuracy: 0.6926 - main_output_loss: 1.6449 - tof_gate_loss: 0.2894 - val_loss: 1.7613 - val_main_output_accuracy: 0.6336 - val_main_output_loss: 1.6480 - val_tof_gate_loss: 0.0675 - learning_rate: 3.1250e-05
# Epoch 80/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.6761 - main_output_accuracy: 0.7242 - main_output_loss: 1.4925 - tof_gate_loss: 0.2705 - val_loss: 1.5806 - val_main_output_accuracy: 0.6727 - val_main_output_loss: 1.4358 - val_tof_gate_loss: 0.0561 - learning_rate: 3.1250e-05
# Epoch 81/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.7192 - main_output_accuracy: 0.7200 - main_output_loss: 1.5345 - tof_gate_loss: 0.2692 - val_loss: 1.5858 - val_main_output_accuracy: 0.6877 - val_main_output_loss: 1.4291 - val_tof_gate_loss: 0.0610 - learning_rate: 3.1250e-05
# Epoch 82/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - loss: 1.6691 - main_output_accuracy: 0.7319 - main_output_loss: 1.4865 - tof_gate_loss: 0.2649 - val_loss: 1.8934 - val_main_output_accuracy: 0.6216 - val_main_output_loss: 1.7177 - val_tof_gate_loss: 0.0707 - learning_rate: 3.1250e-05
# Epoch 83/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.7412 - main_output_accuracy: 0.7143 - main_output_loss: 1.5550 - tof_gate_loss: 0.2800 - val_loss: 1.6192 - val_main_output_accuracy: 0.6907 - val_main_output_loss: 1.5170 - val_tof_gate_loss: 0.0569 - learning_rate: 3.1250e-05
# Epoch 84/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - loss: 1.8019 - main_output_accuracy: 0.6859 - main_output_loss: 1.6136 - tof_gate_loss: 0.2959 - val_loss: 1.4627 - val_main_output_accuracy: 0.7072 - val_main_output_loss: 1.3245 - val_tof_gate_loss: 0.0525 - learning_rate: 3.1250e-05
# Epoch 85/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.7134 - main_output_accuracy: 0.7114 - main_output_loss: 1.5278 - tof_gate_loss: 0.2684
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 127ms/step - loss: 1.7132 - main_output_accuracy: 0.7114 - main_output_loss: 1.5277 - tof_gate_loss: 0.2684 - val_loss: 1.7420 - val_main_output_accuracy: 0.6291 - val_main_output_loss: 1.5786 - val_tof_gate_loss: 0.0622 - learning_rate: 3.1250e-05
# Epoch 86/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.7018 - main_output_accuracy: 0.7049 - main_output_loss: 1.5210 - tof_gate_loss: 0.2790 - val_loss: 1.5537 - val_main_output_accuracy: 0.6967 - val_main_output_loss: 1.4610 - val_tof_gate_loss: 0.0575 - learning_rate: 1.5625e-05
# Epoch 87/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.7099 - main_output_accuracy: 0.7144 - main_output_loss: 1.5248 - tof_gate_loss: 0.2795 - val_loss: 1.5582 - val_main_output_accuracy: 0.6982 - val_main_output_loss: 1.4019 - val_tof_gate_loss: 0.0561 - learning_rate: 1.5625e-05
# Epoch 88/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.6604 - main_output_accuracy: 0.7232 - main_output_loss: 1.4806 - tof_gate_loss: 0.2593 - val_loss: 1.5407 - val_main_output_accuracy: 0.7042 - val_main_output_loss: 1.3948 - val_tof_gate_loss: 0.0554 - learning_rate: 1.5625e-05
# Epoch 89/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 131ms/step - loss: 1.7300 - main_output_accuracy: 0.7073 - main_output_loss: 1.5431 - tof_gate_loss: 0.2772 - val_loss: 1.5069 - val_main_output_accuracy: 0.6802 - val_main_output_loss: 1.3665 - val_tof_gate_loss: 0.0536 - learning_rate: 1.5625e-05
# Epoch 90/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.6585 - main_output_accuracy: 0.7240 - main_output_loss: 1.4807 - tof_gate_loss: 0.2626 - val_loss: 1.6770 - val_main_output_accuracy: 0.6637 - val_main_output_loss: 1.5321 - val_tof_gate_loss: 0.0648 - learning_rate: 1.5625e-05
# Epoch 91/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.6370 - main_output_accuracy: 0.7257 - main_output_loss: 1.4581 - tof_gate_loss: 0.2569 - val_loss: 1.7655 - val_main_output_accuracy: 0.6607 - val_main_output_loss: 1.6065 - val_tof_gate_loss: 0.0664 - learning_rate: 1.5625e-05
# Epoch 92/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.7728 - main_output_accuracy: 0.7011 - main_output_loss: 1.5872 - tof_gate_loss: 0.2933 - val_loss: 1.6333 - val_main_output_accuracy: 0.6922 - val_main_output_loss: 1.5052 - val_tof_gate_loss: 0.0603 - learning_rate: 1.5625e-05
# Epoch 93/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - loss: 1.7834 - main_output_accuracy: 0.6850 - main_output_loss: 1.6007 - tof_gate_loss: 0.2938 - val_loss: 1.6545 - val_main_output_accuracy: 0.6697 - val_main_output_loss: 1.5279 - val_tof_gate_loss: 0.0630 - learning_rate: 1.5625e-05
# Epoch 94/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.7253 - main_output_accuracy: 0.7140 - main_output_loss: 1.5433 - tof_gate_loss: 0.2773
# Epoch 94: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 129ms/step - loss: 1.7251 - main_output_accuracy: 0.7140 - main_output_loss: 1.5431 - tof_gate_loss: 0.2772 - val_loss: 1.6527 - val_main_output_accuracy: 0.6757 - val_main_output_loss: 1.5277 - val_tof_gate_loss: 0.0630 - learning_rate: 1.5625e-05
# Epoch 95/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - loss: 1.7676 - main_output_accuracy: 0.7221 - main_output_loss: 1.5836 - tof_gate_loss: 0.2911 - val_loss: 1.6338 - val_main_output_accuracy: 0.6667 - val_main_output_loss: 1.5075 - val_tof_gate_loss: 0.0645 - learning_rate: 7.8125e-06
# Epoch 96/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 130ms/step - loss: 1.7164 - main_output_accuracy: 0.7265 - main_output_loss: 1.5351 - tof_gate_loss: 0.2766 - val_loss: 1.5763 - val_main_output_accuracy: 0.7177 - val_main_output_loss: 1.4548 - val_tof_gate_loss: 0.0587 - learning_rate: 7.8125e-06
# Epoch 97/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - loss: 1.7494 - main_output_accuracy: 0.7138 - main_output_loss: 1.5683 - tof_gate_loss: 0.2778 - val_loss: 1.5258 - val_main_output_accuracy: 0.7102 - val_main_output_loss: 1.4004 - val_tof_gate_loss: 0.0547 - learning_rate: 7.8125e-06
# Epoch 98/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.7953 - main_output_accuracy: 0.6974 - main_output_loss: 1.6129 - tof_gate_loss: 0.2794 - val_loss: 1.7182 - val_main_output_accuracy: 0.6667 - val_main_output_loss: 1.6025 - val_tof_gate_loss: 0.0695 - learning_rate: 7.8125e-06
# Epoch 99/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.6542 - main_output_accuracy: 0.7336 - main_output_loss: 1.4757 - tof_gate_loss: 0.2641 - val_loss: 1.6031 - val_main_output_accuracy: 0.6892 - val_main_output_loss: 1.4734 - val_tof_gate_loss: 0.0601 - learning_rate: 7.8125e-06
# Epoch 100/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.7143 - main_output_accuracy: 0.7110 - main_output_loss: 1.5283 - tof_gate_loss: 0.2829 - val_loss: 1.6506 - val_main_output_accuracy: 0.6637 - val_main_output_loss: 1.5452 - val_tof_gate_loss: 0.0617 - learning_rate: 7.8125e-06
# Epoch 101/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.7080 - main_output_accuracy: 0.7193 - main_output_loss: 1.5254 - tof_gate_loss: 0.2843 - val_loss: 1.6174 - val_main_output_accuracy: 0.7087 - val_main_output_loss: 1.4855 - val_tof_gate_loss: 0.0634 - learning_rate: 7.8125e-06
# Epoch 102/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 129ms/step - loss: 1.7742 - main_output_accuracy: 0.7056 - main_output_loss: 1.5935 - tof_gate_loss: 0.2803 - val_loss: 1.4612 - val_main_output_accuracy: 0.7027 - val_main_output_loss: 1.3321 - val_tof_gate_loss: 0.0531 - learning_rate: 7.8125e-06
# Epoch 103/160
# 102/114 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 1.7229 - main_output_accuracy: 0.7238 - main_output_loss: 1.5433 - tof_gate_loss: 0.2732
# Epoch 103: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 105ms/step - loss: 1.7268 - main_output_accuracy: 0.7216 - main_output_loss: 1.5470 - tof_gate_loss: 0.2742 - val_loss: 1.5709 - val_main_output_accuracy: 0.6757 - val_main_output_loss: 1.4153 - val_tof_gate_loss: 0.0571 - learning_rate: 7.8125e-06
# Epoch 104/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 127ms/step - loss: 1.7290 - main_output_accuracy: 0.7329 - main_output_loss: 1.5484 - tof_gate_loss: 0.2794 - val_loss: 1.5917 - val_main_output_accuracy: 0.6967 - val_main_output_loss: 1.4524 - val_tof_gate_loss: 0.0581 - learning_rate: 3.9063e-06
# Epoch 105/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 128ms/step - loss: 1.6162 - main_output_accuracy: 0.7208 - main_output_loss: 1.4378 - tof_gate_loss: 0.2676 - val_loss: 1.6166 - val_main_output_accuracy: 0.6607 - val_main_output_loss: 1.5058 - val_tof_gate_loss: 0.0617 - learning_rate: 3.9063e-06
# Epoch 106/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step - loss: 1.6641 - main_output_accuracy: 0.7208 - main_output_loss: 1.4855 - tof_gate_loss: 0.2693 - val_loss: 1.6439 - val_main_output_accuracy: 0.6592 - val_main_output_loss: 1.4993 - val_tof_gate_loss: 0.0625 - learning_rate: 3.9063e-06
# Epoch 107/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 15s 130ms/step - loss: 1.6537 - main_output_accuracy: 0.7211 - main_output_loss: 1.4778 - tof_gate_loss: 0.2538 - val_loss: 1.6857 - val_main_output_accuracy: 0.6532 - val_main_output_loss: 1.5644 - val_tof_gate_loss: 0.0658 - learning_rate: 3.9063e-06
# Epoch 108/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - loss: 1.6425 - main_output_accuracy: 0.7189 - main_output_loss: 1.4652 - tof_gate_loss: 0.2599 - val_loss: 1.7686 - val_main_output_accuracy: 0.6441 - val_main_output_loss: 1.6494 - val_tof_gate_loss: 0.0725 - learning_rate: 3.9063e-06
# Epoch 108: early stopping
# Restoring model weights from the end of the best epoch: 68.
# INFO:tensorflow:Assets written to: hier_ls28/gesture_model_fold_9/assets
# INFO:tensorflow:Assets written to: hier_ls28/gesture_model_fold_9/assets
# Model kaydedildi: hier_ls28/gesture_model_fold_9
# 2025-09-01 16:31:24.328293: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
#
# ✔ Training done.
# Overall OOF H‑F1 Score = 0.8356

# %%
def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
    df_seq = sequence.to_pandas()
    seq_df_copy = df_seq.copy() 


    linear_accel = remove_gravity_from_acc(df_seq, df_seq)
    df_seq['linear_acc_x'], df_seq['linear_acc_y'], df_seq['linear_acc_z'] = linear_accel[:, 0], linear_accel[:, 1], linear_accel[:, 2]
    df_seq['linear_acc_mag'] = np.sqrt(df_seq['linear_acc_x']**2 + df_seq['linear_acc_y']**2 + df_seq['linear_acc_z']**2)
    df_seq['linear_acc_mag_jerk'] = df_seq['linear_acc_mag'].diff().fillna(0)
    angular_vel = calculate_angular_velocity_from_quat(df_seq)
    df_seq['angular_vel_x'], df_seq['angular_vel_y'], df_seq['angular_vel_z'] = angular_vel[:, 0], angular_vel[:, 1], angular_vel[:, 2]
    df_seq['angular_distance'] = calculate_angular_distance(df_seq)

    for col in ['acc_x', 'acc_y', 'acc_z', 'linear_acc_x', 'linear_acc_y', 'linear_acc_z', 'angular_vel_x', 'angular_vel_y', 'angular_vel_z']:
        if col in df_seq.columns:
            df_seq[f'{col}_diff'] = df_seq.groupby('sequence_id')[col].diff().fillna(0)
            df_seq[f'{col}_abs_diff'] = np.abs(df_seq.groupby('sequence_id')[col].diff()).fillna(0) # Mutlak fark

    for i in range(1, 6):
        pixel_cols = [f"tof_{i}_v{p}" for p in range(64)]; tof_data = df_seq[pixel_cols].replace(-1, np.nan)
        df_seq[f'tof_{i}_mean'], df_seq[f'tof_{i}_std'], df_seq[f'tof_{i}_min'], df_seq[f'tof_{i}_max'] = tof_data.mean(axis=1), tof_data.std(axis=1), tof_data.min(axis=1), tof_data.max(axis=1)
        spatial_feats = calculate_spatial_tof_features(seq_df_copy, i)
        df_seq = pd.concat([df_seq, spatial_feats], axis=1)
        
        
    mat_unscaled = df_seq[final_feature_cols].ffill().bfill().fillna(0).values.astype('float32')
    mat_scaled = scaler.transform(mat_unscaled)
    pad_input = pad_sequences([mat_scaled], maxlen=pad_len, padding='post', truncating='post', dtype='float32')

   
    all_preds = [model.predict(pad_input, verbose=0)[0] for model in models] # 主出力のみ取得
    avg_pred = np.mean(all_preds, axis=0)
    print(str(gesture_classes[avg_pred.argmax()]))
    return str(gesture_classes[avg_pred.argmax()])

# %%
if not TRAIN:
    import kaggle_evaluation.cmi_inference_server
    inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict)

    if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
        inference_server.serve()
    else:
        inference_server.run_local_gateway(
            data_paths=(
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
            )
        )
